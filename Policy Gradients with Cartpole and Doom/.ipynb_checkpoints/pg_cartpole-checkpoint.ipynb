# %% [markdown]
# # 0) Installing the dependencies.

# %%
# !pip install tensorflow-gpu
# !pip install numpy
# !pip install gym
# Out:
# Requirement already satisfied: tensorflow-gpu in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (1.12.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (0.32.2)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (0.7.1)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (3.6.1)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.0.6)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.15.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.0.5)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: gast>=0.2.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: absl-py>=0.1.6 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (0.6.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow-gpu) (3.0.1)
# Requirement already satisfied: werkzeug>=0.11.10 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow-gpu) (0.14.1)
# Requirement already satisfied: setuptools in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from protobuf>=3.6.1->tensorflow-gpu) (40.5.0)
# Requirement already satisfied: h5py in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from keras-applications>=1.0.6->tensorflow-gpu) (2.8.0)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (1.15.4)
# Requirement already satisfied: gym in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (0.10.9)
# Requirement already satisfied: six in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from gym) (1.11.0)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from gym) (1.15.4)
# Requirement already satisfied: requests>=2.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from gym) (2.20.1)
# Requirement already satisfied: scipy in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from gym) (1.1.0)
# Requirement already satisfied: pyglet>=1.2.0 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from gym) (1.3.2)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from requests>=2.0->gym) (2.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from requests>=2.0->gym) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from requests>=2.0->gym) (2018.10.15)
# Requirement already satisfied: future in c:\users\usuario\anaconda3\envs\tfp36\lib\site-packages (from pyglet>=1.2.0->gym) (0.17.1)

# %% [markdown]
# # 1) Importing the libraries.

# %%
import tensorflow as tf
import numpy as np
import gym

# %% [markdown]
# # 2) Creating our environment.
#
# To start working with Carpole, we'll first use OpenAI Gym to create our environment.

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped  # unwrapped means no custom Wrappers are used
env.seed(1)  # Considering policy gradients have high variability, we'll use a fixed seed for reproducibility
# Out:
# [1]

# %% [markdown]
# # 3) Setting up our hyperparameters.

# %%
# >>>> ENVIRONMENT HYPERPARAMETERS <<<<
state_size = 4
action_size = env.action_space.n

# >>>> TRAINING HYPERPARAMETERS <<<<
max_episodes = 10000
learning_rate = 0.01
gamma = 0.95 # gamma is the discount rate for future rewards

# %% [markdown]
# # 4) Defining our preprocessing function
#
# In our **Policy Gradient** implementation, we're using a preprocessing function to **perform the discounting of our rewards using gamma**.

# %%
def discount_and_normalize_rewards(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)  # Empty numpy array with the same size of our rewards
    cumulative = 0.0
    
    # We're taking the sum of all rewards discounted by gamma, in reversed order.
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    # Normalizes the rewards by subtracting them to their mean and dividing the result by the standard deviation.
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)
        
    return discounted_episode_rewards

# %% [markdown]
# # 5) Creating our Policy Gradient Neural Network model with TensorFlow
#
# We'll implement the following model:
#
# - The input of our network is a state, which is an array of size 4 containing:
#     - Cart Position;
#     - Cart Velocity;
#     - Pole Angle;
#     - Pole Velocity at Tip.
# - Our neural network contains 3 dense layers. The first two with RELU activation and the third with no activation.
# - The outut of our network is a probability distribution function for the possible actions, so we're using another dense layer with *softmax* activation function. The possible actions for our environment are:
#     - Push cart to the left;
#     - Push cart to the right.

# %%
with tf.name_scope('inputs'):
    # Placeholder used to get the input, in this case the state
    input_ = tf.placeholder(tf.float32, [None, state_size], name='input_')
    # Placeholder used to output the probability distribution for our actions
    actions = tf.placeholder(tf.int32, [None, action_size], name='actions')
    discounted_episode_rewards_ = tf.placeholder(tf.float32, [None, ], name='discounted_episode_rewards')
    
    # This placeholder is used to record the mean reward info to TensorBoard
    mean_reward_ = tf.placeholder(tf.float32, name='mean_reward')
    
    with tf.name_scope('fc1'):
        fc1 = tf.contrib.layers.fully_connected(inputs=input_,
                                                num_outputs = 10,
                                                activation_fn = tf.nn.relu,
                                                weights_initializer = tf.contrib.layers.xavier_initializer())
        
    with tf.name_scope('fc2'):
        fc2 = tf.contrib.layers.fully_connected(inputs=fc1,
                                                num_outputs = action_size,
                                                activation_fn = tf.nn.relu,
                                                weights_initializer = tf.contrib.layers.xavier_initializer())
        
    with tf.name_scope('fc3'):
        fc3 = tf.contrib.layers.fully_connected(inputs=fc2,
                                                num_outputs = action_size,
                                                activation_fn = None,
                                                weights_initializer = tf.contrib.layers.xavier_initializer())
        
    with tf.name_scope('softmax'):
        action_distribution = tf.nn.softmax(fc3)
    
    with tf.name_scope('loss'):
        # Computing the crossentropy of the result of our network, after applying softmax. This works
        # just like a multiclass classification problem, so we can use cross entropy to calculate our loss.
        # If we were using just one class to classify our output probability distribution, we could use
        # tf.nn.sparse_softmax_cross_entropy_with_logits to calculate our loss.
        neg_log_prob = tf.nn.softmax_cross_entropy_with_logits_v2(logits=fc3, labels=actions)
        loss = tf.reduce_mean(neg_log_prob * discounted_episode_rewards_)
        
    with tf.name_scope('train'):
        # Optimizes our parameters using 'learning_rate' and minimizing 'loss'
        train_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

# %% [markdown]
# # 6) Setting up TensorBoard.
#
# To launch TensorBoard, use *tensorboard --logdir=/tensorboard/pg/1* on the command prompt.

# %%
# Setting up TensorBoard writer
writer = tf.summary.FileWriter('/tensorboard/pg/1')

# Recording the losses
tf.summary.scalar('Loss', loss)

# Recording the reward mean
tf.summary.scalar('Reward_mean', mean_reward_)

write_op = tf.summary.merge_all()

# %% [markdown]
# # 7) Training our agent.
#
# Now we'll use our neural network model to output a probability distribution for the possible actions for our agent given an input state, select an action from this distribution and execute it in our environment. When an episode is over, we'll feed all states, actions and rewards from the episode to train our network's parameters.

# %%
all_rewards = []   # Records all rewards so far
total_rewards = 0  # Sum of all rewards
maximum_reward_recorded = 0
episode = 0  # Current episode
episode_states, episode_actions, episode_rewards = [], [], []  # Records all states, actions and rewards for an episode

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for episode in range(max_episodes):
        
        episode_rewards_sum = 0
        state = env.reset()  # Resets the environment before starting the episode
        env.render()
        
        while True:
            # Choosing an action from the network's output, which is a probability distribution over
            # the possible actions given the input state.
            action_probability_distribution = sess.run(action_distribution,
                                                       feed_dict = {input_: state.reshape([1, 4])})
            
            action = np.random.choice(range(action_probability_distribution.shape[1]),
                                      p=action_probability_distribution.ravel())
            
            new_state, reward, done, info = env.step(action)  # Executes the chosen action
            
            # Storing states, actions and rewards
            episode_states.append(state)
            
            # For actions, we'll record a one-hot vector correspondent to the chosen action
            action_ = np.zeros(action_size)
            action_[action] = 1  # Setting index = 'action' to 1
            episode_actions.append(action_)
            
            episode_rewards.append(reward)
            
            if done:
                # Calculating the total reward for the current episode
                episode_rewards_sum = np.sum(episode_rewards_sum)
                
                all_rewards.append(episode_rewards_sum)
                
                total_rewards = np.sum(all_rewards)
                
                mean_reward = np.divide(total_rewards, episode+1)
                
                maximum_reward_recorded = np.amax(all_rewards)
                
                print("===========================")
                print("Episode #", episode)
                print("Reward: ", episode_rewards_sum)
                print("Mean Reward: ", mean_reward)
                print("Max Reward So Far: ", maximum_reward_recorded)
                print("===========================")
                
                # Calculating the discounted rewards for the current episode
                discounted_episode_rewards = discount_and_normalize_rewards(episode_rewards)
                
                # Calculating the loss and training our parameters using the current episode's outputs,
                # that is, feedforward, gradient and backpropagation steps.
                loss_, _ = sess.run([loss, train_opt],
                                    feed_dict={input_: np.vstack(np.array(episode_states)),
                                               actions: np.vstack(np.array(episode_actions)),
                                               discounted_episode_rewards_: discounted_episode_rewards})
                
                # Writing training summaries to TensorBoard
                summary = sess.run(write_op,
                                   feed_dict={input_: np.vstack(np.array(episode_states)),
                                                actions: np.vstack(np.array(episode_actions)),
                                                discounted_episode_rewards_: discounted_episode_rewards,
                                                mean_reward_: mean_reward})
                
                writer.add_summary(summary, episode)
                writer.flush()
                
                # Resetting the stores before beginning a new episode
                episode_states, episode_actions, episode_rewards = [], [], []
                
                break
                
            state = new_state
# Out:
# ===========================
# Episode # 0
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 1
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 2
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 3
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 4
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 5
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 6
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 7
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 8
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 9
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 10
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 11
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 12
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 13
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 14
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 15
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 16
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 17
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 18
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 19
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 20
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 21
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 22
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 23
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 24
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 25
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 26
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 27
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 28
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 29
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 30
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 31
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 32
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 33
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 34
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 35
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 36
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 37
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 38
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 39
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 40
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 41
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 42
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 43
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 44
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 45
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 46
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 47
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 48
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 49
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 50
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 51
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 52
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 53
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 54
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 55
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 56
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 57
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 58
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 59
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 60
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 61
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 62
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 63
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 64
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 65
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 66
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 67
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 68
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 69
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 70
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 71
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 72
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 73
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 74
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 75
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 76
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 77
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 78
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 79
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 80
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 81
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 82
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 83
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 84
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 85
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 86
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 87
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 88
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 89
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 90
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 91
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 92
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 93
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 94
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 95
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 96
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 97
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 98
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 99
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 100
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 101
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 102
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 103
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 104
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 105
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 106
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 107
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 108
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 109
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 110
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 111
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 112
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 113
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 114
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 115
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 116
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 117
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 118
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 119
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 120
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 121
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 122
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 123
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 124
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 125
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 126
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 127
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 128
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 129
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 130
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 131
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 132
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 133
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 134
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 135
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 136
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 137
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 138
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 139
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 140
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 141
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 142
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 143
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 144
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 145
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 146
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 147
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 148
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 149
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 150
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 151
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 152
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 153
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 154
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 155
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 156
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 157
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 158
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 159
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 160
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 161
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 162
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 163
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 164
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 165
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 166
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 167
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 168
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 169
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 170
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 171
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 172
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 173
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 174
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 175
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 176
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 177
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 178
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 179
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 180
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode # 181
# Reward:  0
# Mean Reward:  0.0
# Max Reward So Far:  0
# ===========================
# ===========================
# Episode #